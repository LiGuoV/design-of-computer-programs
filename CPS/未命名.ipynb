# %% [markdown]
# # CPS
# ![image.png](attachment:image.png)
# - 图中显示了一众技术它们在炒作周期中的位置。炒作周期反应人们对新技术的热情如何随着时间的变化。它包括一个驼峰，人们对其非常热情，但技术没有准备好。被遗忘之后，热情关注度下降到慢慢恢复预期并最终达到一定成熟度，使其最终成为系统的一部分进入生产性物品
# ——————
# - 模型代表系统以及允许评估系统的所有其它元素
# - 通常，模型只不过是一个动画运动开发环境
# - 准确的模型不需要非常详细 详细的模型不需要非常精确
